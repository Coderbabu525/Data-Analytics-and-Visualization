# %%
import pandas as pd
dataframe = pd.read_csv("Leeds center air quality data 2020.csv", 
                        header=None, na_values="?")
dataframe.head()
# Out:
#          0         1         2     3      4       5     6        7         8   \
# 0  End Date  End Time        CO  PM10  M_DIR  M_SPED   M_T       NO       NO2
# 1  1/1/2020   1:00:00  0.126628  31.4  149.8       0  -0.5  5.77062   40.9705
# 2  1/1/2020   2:00:00  0.130465  33.7  167.6     0.7   0.6  8.32555  42.53576
# 3  1/1/2020   3:00:00  0.120872  34.3  188.1     1.3   1.2  9.18453  41.91247
# 4  1/1/2020   4:00:00   0.12375  38.3  194.8     0.7   1.9   7.4996  38.86094
#
#          9         10    11       12
# 0  NOXasNO2        O3  PM25      SO2
# 1  49.81866  12.04072  27.9  1.76441
# 2  55.30142  10.77678  32.4  1.49975
# 3  55.99523  10.97635  30.1  1.38947
# 4  50.36017  10.57721  30.8  1.19098

# %%
# summarize the number of rows with missing values for each column
for i in range(dataframe.shape[1]):
	# count number of rows with missing values
	n_miss = dataframe[[i]].isnull().sum()
	perc = n_miss / dataframe.shape[0] * 100
	print('> %d, Missing: %d (%.1f%%)' % (i, n_miss, perc))
# Out:
# > 0, Missing: 0 (0.0%)
# > 1, Missing: 0 (0.0%)
# > 2, Missing: 63 (0.7%)
# > 3, Missing: 277 (3.2%)
# > 4, Missing: 120 (1.4%)
# > 5, Missing: 120 (1.4%)
# > 6, Missing: 120 (1.4%)
# > 7, Missing: 69 (0.8%)
# > 8, Missing: 69 (0.8%)
# > 9, Missing: 69 (0.8%)
# > 10, Missing: 269 (3.1%)
# > 11, Missing: 255 (2.9%)
# > 12, Missing: 93 (1.1%)

# %%
# knn imputation transform
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
# load dataset
dataframe = pd.read_csv("Leeds center air quality data 2020.csv", header=None, 
                        na_values="?")
# split into input and output elements
data = dataframe.values
ix = [i for i in range(2, data.shape[1]) if i != 13]
X, y = data[:, ix], data[:, 12]
X = np.delete(X, 0, 0)
#print(X)
# print total missing
print('Missing before KNN imputation: %d' % sum(pd.isna(X).flatten()))
# define imputer
imputer = KNNImputer()
# fit on the dataset
imputer.fit(X)
# transform the dataset
Xtrans = imputer.transform(X)
#print(Xtrans)
# print total missing
print('Missing after KNN imputation: %d' % sum(pd.isna(Xtrans).flatten()))
np.savetxt("Updated Leeds center air quality data 2020.csv", Xtrans, delimiter=",", 
           header="CO, PM10, M_DIR, M_SPED, M_T, NO, NO2, NOXasNO2, O3, PM25, SO2")
# Out:
# Missing before KNN imputation: 1524
# Missing after KNN imputation: 0
